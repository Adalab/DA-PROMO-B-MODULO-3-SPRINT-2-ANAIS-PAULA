# %%
import pandas as pd

# %%
df = pd.read_excel('./netflix_titles.xlsx')

# %%
df.head()
# Out:
#   duration_minutes duration_seasons     type  \
# 0               90              NaN    Movie
# 1               94              NaN    Movie
# 2              NaN                1  TV Show
# 3              NaN                1  TV Show
# 4               99              NaN    Movie
#
#                                      title           date_added  release_year  \
# 0  Norm of the North: King Sized Adventure  2019-09-09 00:00:00        2019.0
# 1               Jandino: Whatever it Takes  2016-09-09 00:00:00        2016.0
# 2                       Transformers Prime  2018-09-08 00:00:00        2013.0
# 3         Transformers: Robots in Disguise  2018-09-08 00:00:00        2016.0
# 4                             #realityhigh  2017-09-08 00:00:00        2017.0
#
#      rating                                        description     show_id
# 0     TV-PG  Before planning an awesome wedding for his gra...  81145628.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6236 entries, 0 to 6235
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   duration_minutes  4267 non-null   object
#  1   duration_seasons  1971 non-null   object
#  2   type              6235 non-null   object
#  3   title             6235 non-null   object
#  4   date_added        6223 non-null   object
#  5   release_year      6234 non-null   float64
#  6   rating            6223 non-null   object
#  7   description       6233 non-null   object
#  8   show_id           6232 non-null   float64
# dtypes: float64(2), object(7)
# memory usage: 438.6+ KB

# %%
df[df['release_year'].isnull()]
# Out:
#           duration_minutes duration_seasons   type  \
# 2017                    40              NaN  Movie
# 4525   and probably will."         80188902    NaN
#
#                                 title date_added  release_year rating  \
# 2017  The Memphis Belle: A Story of a        NaN           NaN    NaN
# 4525                              NaN        NaN           NaN    NaN
#
#      description  show_id
# 2017         NaN      NaN
# 4525         NaN      NaN

# %%
df.dropna(subset='release_year',inplace=True)

# %% [markdown]
# Vemos que hay 4 columnas mal casteadas: duration_minutes, duration_seasons, release_year y show_id, tienen que estar a integer.

# %%
list(df['date_added'].unique())
# Out:
# [datetime.datetime(2019, 9, 9, 0, 0),
#  datetime.datetime(2016, 9, 9, 0, 0),
#  datetime.datetime(2018, 9, 8, 0, 0),
#  datetime.datetime(2017, 9, 8, 0, 0),
#  datetime.datetime(2015, 9, 8, 0, 0),
#  datetime.datetime(2018, 9, 7, 0, 0),
#  datetime.datetime(2017, 9, 7, 0, 0),
#  datetime.datetime(2019, 9, 6, 0, 0),
#  datetime.datetime(2018, 9, 6, 0, 0),
#  datetime.datetime(2017, 9, 6, 0, 0),
#  datetime.datetime(2016, 9, 6, 0, 0),
#  datetime.datetime(2019, 9, 5, 0, 0),
#  datetime.datetime(2018, 9, 5, 0, 0),
#  datetime.datetime(2017, 9, 5, 0, 0),
#  datetime.datetime(2019, 9, 4, 0, 0),
#  datetime.datetime(2018, 9, 4, 0, 0),
#  datetime.datetime(2017, 9, 4, 0, 0),
#  datetime.datetime(2019, 9, 30, 0, 0),
#  datetime.datetime(2018, 9, 30, 0, 0),
#  datetime.datetime(2017, 9, 30, 0, 0),
#  datetime.datetime(2016, 9, 30, 0, 0),
#  datetime.datetime(2018, 9, 3, 0, 0),
#  datetime.datetime(2018, 9, 29, 0, 0),
#  datetime.datetime(2017, 9, 29, 0, 0),
# ...

# %%
df[df['date_added']== 'This documentary centers on the crew of the B-17 Flying Fortress Memphis Belle as it prepares to execute a strategic bombing mission over Germany.']
# Out:
#       duration_minutes     duration_seasons  type  title  \
# 2018  Flying Fortress"  2017-03-31 00:00:00  1944  TV-PG
#
#                                              date_added  release_year rating  \
# 2018  This documentary centers on the crew of the B-...    80119194.0    NaN
#
#      description  show_id
# 2018         NaN      NaN

# %% [markdown]
# Vemos que esta fila está mal ordenada, por lo que decidimos que al ser un df de uso académico, la eliminamos

# %%
df.drop(index = 2018, axis=0, inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#      duration_minutes duration_seasons     type  \
# 0                  90              NaN    Movie
# 1                  94              NaN    Movie
# 2                 NaN                1  TV Show
# 3                 NaN                1  TV Show
# 4                  99              NaN    Movie
# ...               ...              ...      ...
# 6228              NaN               13  TV Show
# 6229              NaN                4  TV Show
# 6230               60              NaN    Movie
# 6231              NaN                2  TV Show
# 6232              NaN               10  TV Show
#
#                                             title           date_added  \
# 0         Norm of the North: King Sized Adventure  2019-09-09 00:00:00
# 1                      Jandino: Whatever it Takes  2016-09-09 00:00:00
# 2                              Transformers Prime  2018-09-08 00:00:00
# 3                Transformers: Robots in Disguise  2018-09-08 00:00:00
# ...

# %%
df.head(2)
# Out:
#   duration_minutes duration_seasons   type  \
# 0               90              NaN  Movie
# 1               94              NaN  Movie
#
#                                      title           date_added  release_year  \
# 0  Norm of the North: King Sized Adventure  2019-09-09 00:00:00        2019.0
# 1               Jandino: Whatever it Takes  2016-09-09 00:00:00        2016.0
#
#   rating                                        description     show_id
# 0  TV-PG  Before planning an awesome wedding for his gra...  81145628.0
# 1  TV-MA  Jandino Asporaat riffs on the challenges of ra...  80117401.0

# %% [markdown]
# Casteamos la fecha para que solo nos salga la fecha y no la hora

# %%
from datetime import date

# %%
df['date_added']=pd.to_datetime(df['date_added'], format= "%Y-%m-%d")

# %%
df['date_added']
# Out:
# 0      2019-09-09
# 1      2016-09-09
# 2      2018-09-08
# 3      2018-09-08
# 4      2017-09-08
#           ...
# 6231          NaT
# 6232          NaT
# 6233          NaT
# 6234          NaT
# 6235          NaT
# Name: date_added, Length: 6233, dtype: datetime64[ns]

# %% [markdown]
# Casteamos realease year a int

# %%
df['release_year'] = df['release_year'].astype('int64')

# %%
df['release_year'].dtypes
# Out:
# dtype('int64')

# %%
df['release_year'].unique()
# Out:
# array([2019, 2016, 2013, 2017, 2014, 2015, 2009, 2012, 2010, 2018, 2011,
#        2004, 2000, 1983, 1982, 2006, 2005, 2002, 1997, 2008, 2007, 2003,
#        1981, 1991, 1994, 1988, 1976, 1973, 1974, 1989, 1986, 1984, 1978,
#        1998, 1972, 1979, 1960, 1959, 2001, 1995, 1992, 1990, 1975, 1985,
#        1980, 1970, 1996, 1967, 1999, 1987, 1968, 1993, 2020, 1958, 1965,
#        1956, 1962, 1955, 1977, 1945, 1946, 1942, 1944, 1947, 1943, 1969,
#        1954, 1966, 1971, 1964, 1925, 1963])

# %%
df.to_csv('./netflix-tableau.csv')
